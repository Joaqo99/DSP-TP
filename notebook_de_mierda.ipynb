# %%
import numpy as np
import pandas as pd
import time
import audio_functions as auf

# %%
t60_list = np.linspace(0.2, 0.8, 10)

dmic_list = np.linspace(0.1, 1, 5)

source_x_list = np.random.randint(10, size=5)
source_y_list = np.random.randint(10, size=5)
source_list = []

for i in range(5):
    x_pos = int(source_x_list[i])
    y_pos = int(source_y_list[i])
    source_pos = [x_pos, y_pos, 1]
    source_list.append(source_pos)

mic_x_list = np.random.randint(4, high=10, size=5)
mic_y_list = np.random.randint(4, high=10, size=5)
mic_list = []

for i in range(5):
    x_pos = int(mic_x_list[i])
    y_pos = int(mic_y_list[i])
    mic_pos = [x_pos, y_pos, 1]
    mic_list.append(mic_pos)

# %%
print(mic_list)
# Out:
# [[9, 5, 1], [6, 5, 1], [5, 8, 1], [9, 5, 1], [4, 8, 1]]

# %%
names = []

for t60 in t60_list:
    for d in dmic_list:
        for s_pos in source_list:
            for m_pos in mic_list:
                sim_name = f"sim_T{t60:.2f}s_d{d:.1f}_s[{s_pos[0]:.1f},{s_pos[1]:.1f},{s_pos[2]:.1f}]_m[{m_pos[0]:.1f},{m_pos[1]:.1f},{m_pos[2]:.1f}]"

                mods = [
                    {"var":"room", "param":'dim', "value":[10, 10, 3]},
                    {"var":"room",      "param":"t60",      "value": float(t60)},
                    {"var":"mic_array", "param":"d",        "value": float(d)},
                    {"var":"mic_array", "param":"position", "value":s_pos},
                    {"var":"source",    "param":"position", "value":m_pos}]

                auf.gen_simulation_dict(sim_name, *mods)

                names.append(sim_name)
# Out:
#   Cell In[18], line 4
#     for d in dmic_list:
#     ^
# IndentationError: expected an indented block after 'for' statement on line 3

# %%
df = auf.process_simulation_data(*names, df_values= ["room.t60", "mic_array.d", "mic_array.position", "source.position"])
df.to_csv("simulación_rt60.csv")
# Out:
# c:\Users\KP\anaconda3\Lib\site-packages\pyroomacoustics\simulation\ism.py:187: RuntimeWarning: divide by zero encountered in divide
#   oct_band_amplitude = att / dist
# e:\Users\Usuario\Documents\Untref\2025\Primer Cuatrimestre\Procesamiento Digital de Señales\TP Tiemp de Arribo\DSP-TP\filters.py:78: RuntimeWarning: invalid value encountered in divide
#   gamma_12 = phi / (np.sqrt(gx1x1 * gx2x2) + epsilon)

# %%
df
# Out:
#                                           sim_name   method  expected_theta  \
# 0    sim_T0.20s_d0.1_s[9.0,0.0,1.0]_m[9.0,8.0,1.0]  Classic          88.568
# 1    sim_T0.20s_d0.1_s[9.0,0.0,1.0]_m[9.0,8.0,1.0]     ROTH          88.568
# 2    sim_T0.20s_d0.1_s[9.0,0.0,1.0]_m[9.0,8.0,1.0]     PHAT          88.568
# 3    sim_T0.20s_d0.1_s[9.0,0.0,1.0]_m[9.0,8.0,1.0]     SCOT          88.568
# 4    sim_T0.20s_d0.1_s[9.0,0.0,1.0]_m[9.0,8.0,1.0]   ECKART          88.568
# ..                                             ...      ...             ...
# 745  sim_T0.20s_d1.0_s[6.0,5.0,1.0]_m[7.0,6.0,1.0]     ROTH          45.000
# 746  sim_T0.20s_d1.0_s[6.0,5.0,1.0]_m[7.0,6.0,1.0]     PHAT          45.000
# 747  sim_T0.20s_d1.0_s[6.0,5.0,1.0]_m[7.0,6.0,1.0]     SCOT          45.000
# 748  sim_T0.20s_d1.0_s[6.0,5.0,1.0]_m[7.0,6.0,1.0]   ECKART          45.000
# 749  sim_T0.20s_d1.0_s[6.0,5.0,1.0]_m[7.0,6.0,1.0]       HT          45.000
#
#      theta_prom    error              est_theta_list  room.t60  mic_array.d  \
# 0        91.367  0.00024     [0.0, 94.1, 90.0, 90.0]       0.2          0.1
# 1        92.050  0.00037    [0.0, 94.1, 92.05, 90.0]       0.2          0.1
# 2        92.050  0.00037    [0.0, 94.1, 92.05, 90.0]       0.2          0.1
# 3        92.050  0.00037    [0.0, 94.1, 92.05, 90.0]       0.2          0.1
# 4        92.050  0.00037    [0.0, 94.1, 92.05, 90.0]       0.2          0.1
# ..          ...      ...                         ...       ...          ...
# 745      30.433  0.00655   [0.0, 35.45, 29.75, 26.1]       0.2          1.0
# 746      30.433  0.00655   [0.0, 35.45, 29.75, 26.1]       0.2          1.0
# 747      30.433  0.00655   [0.0, 35.45, 29.75, 26.1]       0.2          1.0
# 748      29.053  0.00785  [0.0, 36.15, 27.17, 23.84]       0.2          1.0
# 749      30.433  0.00655   [0.0, 35.45, 29.75, 26.1]       0.2          1.0
#
#     mic_array.position source.position
# 0            [9, 0, 1]       [9, 8, 1]
# 1            [9, 0, 1]       [9, 8, 1]
# 2            [9, 0, 1]       [9, 8, 1]
# 3            [9, 0, 1]       [9, 8, 1]
# 4            [9, 0, 1]       [9, 8, 1]
# ..                 ...             ...
# 745          [6, 5, 1]       [7, 6, 1]
# 746          [6, 5, 1]       [7, 6, 1]
# 747          [6, 5, 1]       [7, 6, 1]
# 748          [6, 5, 1]       [7, 6, 1]
# 749          [6, 5, 1]       [7, 6, 1]
#
# [750 rows x 10 columns]

# %%
room_data = source_list, mic_list

# %%
room_data
# Out:
# ([[9, 0, 1], [6, 0, 1], [9, 7, 1], [6, 9, 1], [6, 5, 1]],
#  [[9, 8, 1], [5, 5, 1], [5, 4, 1], [7, 5, 1], [7, 6, 1]])
