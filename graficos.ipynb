# %%
import plot
import pandas as pd

# %%
df = pd.read_csv("simulación_anecoicas.csv")
df = df.drop("Unnamed: 0", axis=1)
df = df[df["error"] != 1.0]
df
# Out:
#                                             sim_name   method  expected_theta  \
# 0    sim_anechoic_d0.1_s[8.0,2.0,1.0]_m[5.0,5.0,1.0]  Classic          46.975
# 1    sim_anechoic_d0.1_s[8.0,2.0,1.0]_m[5.0,5.0,1.0]     ROTH          46.975
# 2    sim_anechoic_d0.1_s[8.0,2.0,1.0]_m[5.0,5.0,1.0]     PHAT          46.975
# 3    sim_anechoic_d0.1_s[8.0,2.0,1.0]_m[5.0,5.0,1.0]     SCOT          46.975
# 4    sim_anechoic_d0.1_s[8.0,2.0,1.0]_m[5.0,5.0,1.0]   ECKART          46.975
# ..                                               ...      ...             ...
# 595  sim_anechoic_d0.1_s[8.0,1.0,1.0]_m[8.0,7.0,1.0]     ROTH          88.091
# 596  sim_anechoic_d0.1_s[8.0,1.0,1.0]_m[8.0,7.0,1.0]     PHAT          88.091
# 597  sim_anechoic_d0.1_s[8.0,1.0,1.0]_m[8.0,7.0,1.0]     SCOT          88.091
# 598  sim_anechoic_d0.1_s[8.0,1.0,1.0]_m[8.0,7.0,1.0]   ECKART          88.091
# 599  sim_anechoic_d0.1_s[8.0,1.0,1.0]_m[8.0,7.0,1.0]       HT          88.091
#
# ...

# %%
plot.plot_bars_error(df, "method", "error", errorbar="sd", grid=True, y_label="Valor medio del error angular", x_label="Ponderación", figsize=(5, 3.5))
# Out:
# c:\Users\joaqo\OneDrive\Escritorio\facultad\materias\DSP\DSP-TP\plot.py:439: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data, x=x, y=y, hue=hue, errorbar=errorbar, palette="hls")

# %%
import audio_functions as auf

auf.angle_error(180.0, 90.0)
# Out:
# 0.25

# %%
df1 = pd.read_csv("simulación_d_s_m.csv")
df1 = df1.drop("Unnamed: 0", axis=1)
#df1 = df1[df1["error"] != 1.0]
df1
# Out:
#                                                sim_name   method  \
# 0     sim_T0.20s_d0.1_mic[5.0,2.0,1.0]_src[1.0,1.0,1.0]  Classic
# 1     sim_T0.20s_d0.1_mic[5.0,2.0,1.0]_src[1.0,1.0,1.0]     ROTH
# 2     sim_T0.20s_d0.1_mic[5.0,2.0,1.0]_src[1.0,1.0,1.0]     PHAT
# 3     sim_T0.20s_d0.1_mic[5.0,2.0,1.0]_src[1.0,1.0,1.0]     SCOT
# 4     sim_T0.20s_d0.1_mic[5.0,2.0,1.0]_src[1.0,1.0,1.0]   ECKART
# ...                                                 ...      ...
# 2995  sim_T0.80s_d0.1_mic[5.0,2.0,1.0]_src[9.0,9.0,1.0]     ROTH
# 2996  sim_T0.80s_d0.1_mic[5.0,2.0,1.0]_src[9.0,9.0,1.0]     PHAT
# 2997  sim_T0.80s_d0.1_mic[5.0,2.0,1.0]_src[9.0,9.0,1.0]     SCOT
# 2998  sim_T0.80s_d0.1_mic[5.0,2.0,1.0]_src[9.0,9.0,1.0]   ECKART
# 2999  sim_T0.80s_d0.1_mic[5.0,2.0,1.0]_src[9.0,9.0,1.0]       HT
#
#       expected_theta  theta_prom    error  \
# 0            166.608     172.840  0.00120
# 1            166.608     180.000  0.00554
# 2            166.608     180.000  0.00554
# ...

# %%
plot.plot_lines_error(df1, "mic-source distance", "error", hue="method", errorbar="sd", grid=True, y_label="Valor medio del error angular", x_label="Distancia Fuente - Arreglo [m]", figsize=(6,3.5))
